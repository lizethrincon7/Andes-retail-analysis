# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto.
# Sigue cada paso y espera feedback del evaluador.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop o en Tableau.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 2: Preparación de los datos
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
# - Especifica qué KPIs incluirás y por qué.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
# - Especifica qué filtros o segmentadores usaras.

# %% [markdown]
# ### Diseño y planificación
# ✏️ Describe aquí brevemente tu planificación antes de construir el dashboard.
# - De forma general, previo a la construcción del dashboard, es fundamental entender el objetivo del tablero, ¿que decisión debería poder tomar el usuario con este reporte? y otras preguntas clave que ayuden a la dirección a: entender el desempeño general, detectar oportunidades, identificar problemas rápidamente, y tomar decisiones comerciales y operativas.
# - Seguido de definir la jerarquía o el orden de lectura en ambas páginas del overview y detalles.
# - La selección de visualizaciones basado en la pregunta que responderá el tipo de gráfico.
# - Definición de colores y contraste se usarán para destacar los más importante.
#
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Especifica qué KPIs incluirás y por qué: (3-4 KPIs)
# - Ingresos: Mide el valor total de las ventas generadas en un periodo, nos permite evaluar el volumen de negocio y si se esta generando suficiente actividad comercial.
# - Margen de utilidad %: Mide que % de los ingresos se convierten en ganancia y nos permite conocer si el negocio esta siendo rentable.
# - Crecicmiento YoY:  Es el cambio porcentual respecto al mismo periodo del año anterior y permite evaluar la evolución real del negocio, si esta creciendo o decreciendo.
# - ¿Qué regiones o países generan más ingresos? Permite identificar que mercados sostienen el negocio y donde existen oprotunidades o riesgos.
#
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - **Ingresos**:
# - Mostrar en una tajeta los ingresos totales para responder rápidamente a la pregunta ¿como van las ventas del negocio? en una lectura rápida.
# - Gráfico de lineas dobles para comparar el desempeño de los ingresos entre años, si uno fue mejor que el otro, o en que periodo hubo mejor desempeño.
#
# - **Margen de utilidad**:
# - Mostrar en una tarjeta el % de margen para responder la pregunta ¿estamos siendo rentables? compararlo rapidamente con el objetivo.
#
# - **Crecimiento YoY:**
# - Mostrar en una tarjeta el % con una flecha positiva o negativa para responder la pregunta si estamos creciendo con respecto al año previo.
#
# - Linea comparativa entre el año 2024 y 2025, para identificar la tendencia general.
#
# - **Regiones o países generan más ingresos**:
# - Mapa geográfico interactivo, en función alos ingresos para identificar rapidamente que países o regiones lideran
#
#
# Descripción de la jerarquía visual:
# - Título
# - Tarjetas de ingresos, margen y crecimiento
# - Grafico de lineas de ingresos
# - Gráfico comparativo de crecimiento YoY
# - Mapa geográfico interactivo
#
# Filtro(s)
# - Año
#
#
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - TreeMap por dimension de categoría de producto vs. ingresos que permitpe identificar categorias dominantes y responder, ¿que productos venden más?
# - Gráfico de líneas por mes y año comparando el total de unidades vendidas, que expliquen el comportamiento de las ventas totales.
# - Grafico de cascada que ayude a descifrar que factores y como impactaron en el comportamiento de la ventas, margen, etc.
# - Heatmap de crecimiento Filas: País Columnas: Categoría Valor: % crecimiento respondiendo a la pregunta, ¿que combinaciones impulsan el creciemiento?
#
#
# Filtros (mínimo 2)
# - Año
# - Región

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# El compartivo mensual de ventas entre los años muestra que no se tiene una temporada alta lineal, sino un comportamiento de picos en los extremos del año (Diciembre, Enero, Febrero)
#
# **C (Complicación):**
# Se identifica un decrecimiento del -6.80% con respecto al año previo.
# Entre los meses de junio, julio y agosto se observa un estancamiento crítico de ventas.
# 2025 fue un año mucho más volátil que 2024 en términos de % de margen de utilidad, en Q2 se experimento una caída pronunciada muy por debajo del promedio histórico.
#
# **Q (Pregunta):**
# ¿Es un problema de costos? ¿que factores explican la caída del margen y ventas entre los periodos Q2 Y Q3?
#
# **A (Respuesta):**
# En la pestaña de detalles se puede indentificar en el grafico de unidades mensuales vendidas por año que, el negocio se estancó de junio a agosto, apenas vendiendo 1,000 unidades por mes vs. las más de 4,000 de inicio de año.
#
#
# ---
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# La variación de costos YoY en el tiempo muestra un aumento significante en los costos
#
# **C (Complicación):**
# Q2 de 2024 acumuló un incremento masivo de costos de $0.4 millones, haciendo que en el Q2 de 2025 el margen de utilidad cayera por debajo del 34.5%, el punto más bajo del año.
#
# **Q (Pregunta):**
# ¿Es un problema por locación o estacional? ¿Que influye el aumento de costos?
#
# **A (Respuesta):**
# El deterioro del margen en 2025 fue impulsado principalmente por incrementos de costos en Q2 y Q3.
# Falta un producto ancla para la estación de verano.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# Equipo, durante el ultimo periodo de ventas (2025), Andes Retail Group, presentó una caída del 6.80 % en crecimiento, respecto al periodo anterior (2024), provocada por un desplome crítico en el volumen de unidades vendidas y una incapacidad de reaccionar ante los costos logísticos/operativos durante el segundo trimestre (Q2).
# Al tener un portafolio tan dividido y equilibrado (26% Deportes, 25% Electrónica, etc.), cuando el mercado se enfría en verano, todo el negocio se hunde de manera uniforme porque no hay un producto que rescate la temporada.
#
# Sugeriría los siguientes planes de acción:
# 1. Reestructurar el Portafolio de Productos: Desarrollar o adquirir líneas de productos ancla para la estación de verano.
# 2. Descubrir qué causó el repunte de costos de $0.4 millones. Se deben renegociar contratos con proveedores, negociar tarifas de envío, etc.
# 3. En Perú: Frenar la inversión en Ropa y Deportes (donde se ha tenido una caída del 20 y 11% respectivamente) y potenciar la categoría de Hogar, que es la única que muestra un crecimiento positivo (+10%).
# 4. En Colombia: Investigar qué causó la caída del -27% en Electrónica y mejorar la estrategia en Deportes (+6%), que demostró resiliencia.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **una** de las siguientes opciones, según la herramienta que hayas utilizado:
# - 🔗 Link público del dashboard publicado (Power BI Service o Tableau Public), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %% [markdown]
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
https://app.powerbi.com/groups/me/reports/ae4ad29d-29e2-431a-95ca-ac29fca7143d?ctid=afbb3ac3-c9c2-478d-80df-3fc0694a149f&pbi_source=linkShare

Adicional "Subi mi proyecto a la plataforma"
